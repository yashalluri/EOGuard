# %%
import logging
import time
from graphy_bois import GraphyClass

# Suppress logs from cmdstanpy
logging.getLogger("cmdstanpy").setLevel(logging.WARNING)

def graph_generator(file_path):
    generator = GraphyClass(file_path)
    generator.create_graph()

    display(generator.fig)  # Display the initial FigureWidget

    while True:
        generator.update_graph()
        time.sleep(0)  # Adjust refresh rate

# %%
try: 
    graph_generator("./data/Fearless_709H-10_31-11_07.csv")
except KeyboardInterrupt:
    print("InterruptedError")
# Out:
# FigureWidget({
#     'data': [{'line': {'color': 'blue', 'width': 2},
#               'marker': {'color': 'blue', 'size': 2},
#               'mode': 'lines+markers',
#               'name': 'Flow Rate',
#               'type': 'scatter',
#               'uid': '09da22e2-dacd-4f05-86fb-df89f382e500',
#               'x': [],
#               'y': []},
#              {'line': {'color': 'green', 'width': 2},
#               'mode': 'lines',
#               'name': 'Predicted Flow Rate',
#               'type': 'scatter',
#               'uid': '1d2d34ae-ba30-4152-8b54-ae0cbe024d5a',
#               'x': [],
#               'y': []}],
#     'layout': {'template': '...',
#                'xaxis': {'range': [0, 100], 'title': {'text': 'Time'}},
#                'yaxis': {'range': [0, 611.36115], 'title': {'text': 'Value'}}}
# })
# /Users/harsha_gurram/repos/EOGuard/graphy_bois.py:144: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#
# /Users/harsha_gurram/repos/EOGuard/graphy_bois.py:144: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#
# /Users/harsha_gurram/repos/EOGuard/graphy_bois.py:144: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#
# /Users/harsha_gurram/repos/EOGuard/graphy_bois.py:144: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#
# /Users/harsha_gurram/repos/EOGuard/graphy_bois.py:144: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#
# /Users/harsha_gurram/repos/EOGuard/graphy_bois.py:144: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#
# /Users/harsha_gurram/repos/EOGuard/graphy_bois.py:144: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#
# /Users/harsha_gurram/repos/EOGuard/graphy_bois.py:144: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#
# /Users/harsha_gurram/repos/EOGuard/graphy_bois.py:144: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#
# /Users/harsha_gurram/repos/EOGuard/graphy_bois.py:144: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#
# /Users/harsha_gurram/repos/EOGuard/graphy_bois.py:144: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#
# /Users/harsha_gurram/repos/EOGuard/graphy_bois.py:144: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#
# /Users/harsha_gurram/repos/EOGuard/graphy_bois.py:144: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#
# /Users/harsha_gurram/repos/EOGuard/graphy_bois.py:144: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#
# /Users/harsha_gurram/repos/EOGuard/graphy_bois.py:144: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#
# /Users/harsha_gurram/repos/EOGuard/graphy_bois.py:144: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#
# /Users/harsha_gurram/repos/EOGuard/graphy_bois.py:144: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#
# /Users/harsha_gurram/repos/EOGuard/graphy_bois.py:144: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#
# /Users/harsha_gurram/repos/EOGuard/graphy_bois.py:144: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#
# /Users/harsha_gurram/repos/EOGuard/graphy_bois.py:144: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#
# /Users/harsha_gurram/repos/EOGuard/graphy_bois.py:144: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#
# /Users/harsha_gurram/repos/EOGuard/graphy_bois.py:144: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#
# /Users/harsha_gurram/repos/EOGuard/graphy_bois.py:144: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#
# /Users/harsha_gurram/repos/EOGuard/graphy_bois.py:144: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#
# /Users/harsha_gurram/repos/EOGuard/graphy_bois.py:144: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#
# /Users/harsha_gurram/repos/EOGuard/graphy_bois.py:144: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#
# /Users/harsha_gurram/repos/EOGuard/graphy_bois.py:144: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#
# /Users/harsha_gurram/repos/EOGuard/graphy_bois.py:144: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#
# /Users/harsha_gurram/repos/EOGuard/graphy_bois.py:144: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#
# /Users/harsha_gurram/repos/EOGuard/graphy_bois.py:144: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#
# /Users/harsha_gurram/repos/EOGuard/graphy_bois.py:144: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#
# /Users/harsha_gurram/repos/EOGuard/graphy_bois.py:144: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#
# /Users/harsha_gurram/repos/EOGuard/graphy_bois.py:144: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#
# /Users/harsha_gurram/repos/EOGuard/graphy_bois.py:144: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#
# /Users/harsha_gurram/repos/EOGuard/graphy_bois.py:144: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#
# /Users/harsha_gurram/repos/EOGuard/graphy_bois.py:144: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#
# /Users/harsha_gurram/repos/EOGuard/graphy_bois.py:144: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#
# /Users/harsha_gurram/repos/EOGuard/graphy_bois.py:144: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#
# /Users/harsha_gurram/repos/EOGuard/graphy_bois.py:144: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#
# /Users/harsha_gurram/repos/EOGuard/graphy_bois.py:144: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#
# /Users/harsha_gurram/repos/EOGuard/graphy_bois.py:144: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#
# /Users/harsha_gurram/repos/EOGuard/graphy_bois.py:144: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#
# /Users/harsha_gurram/repos/EOGuard/graphy_bois.py:144: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#
# /Users/harsha_gurram/repos/EOGuard/graphy_bois.py:144: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#
# /Users/harsha_gurram/repos/EOGuard/graphy_bois.py:144: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#
# /Users/harsha_gurram/repos/EOGuard/graphy_bois.py:144: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#
# /Users/harsha_gurram/repos/EOGuard/graphy_bois.py:144: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#
# /Users/harsha_gurram/repos/EOGuard/graphy_bois.py:144: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#
# /Users/harsha_gurram/repos/EOGuard/graphy_bois.py:144: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#
# /Users/harsha_gurram/repos/EOGuard/graphy_bois.py:144: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#
# /Users/harsha_gurram/repos/EOGuard/graphy_bois.py:144: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#
# /Users/harsha_gurram/repos/EOGuard/graphy_bois.py:144: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#
# /Users/harsha_gurram/repos/EOGuard/graphy_bois.py:144: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#
# /Users/harsha_gurram/repos/EOGuard/graphy_bois.py:144: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#
# /Users/harsha_gurram/repos/EOGuard/graphy_bois.py:144: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#
# /Users/harsha_gurram/repos/EOGuard/graphy_bois.py:144: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#
# /Users/harsha_gurram/repos/EOGuard/graphy_bois.py:144: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#
# /Users/harsha_gurram/repos/EOGuard/graphy_bois.py:144: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# InterruptedError
# /Users/harsha_gurram/repos/EOGuard/graphy_bois.py:144: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#
# /Users/harsha_gurram/repos/EOGuard/graphy_bois.py:144: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
